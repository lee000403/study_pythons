# %% [markdown]
# <a href="https://colab.research.google.com/github/lee000403/toy_pythons/blob/main/Whiles_LDH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first = 1
while first <= 3:
  print(first)
  first += 1
print("End")
# Out:
# 1
# 2
# 3
# End

# %%
def solution(n):
    answer = 0
    for i in range(1, n+1):
        if n%i == 0:
            answer += i
    print(answer)

solution(12)
solution(5)
# Out:
# 28
# 6
