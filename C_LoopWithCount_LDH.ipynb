# %% [markdown]
# <a href="https://colab.research.google.com/github/lee000403/toy_pythons/blob/main/C_LoopWithCount_LDH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# while 문으로 숫자 세기

# %%
count = 1
while count < 6:
  print(count)
  count = count + 1
print("END")
# Out:
# 1
# 2
# 3
# 4
# 5
# END
